# %% [markdown]
# <p style="text-align: center;"> <span style="color:firebrick"> <font size="5"> <b> USC Marshall School of Business </b> </font> </p> </span>
#
# <p style="text-align: center;"> <b> <font font size="6"> DSO 559: HW #6 </p> </b></font>

# %% [markdown]
# ## <span style="color:blue">  REPLACE THIS TEXT WITH YOUR NAME </span>

# %% [markdown]
# ## <span style="color:firebrick"> Assignment Description </span>

# %% [markdown]
# The data is drawn from the **Federal Depository Insurance Corporation** (FDIC) for 2019 to 2021 for member banks in California, Illinois, Massachusetts, and New York (https://www7.fdic.gov/sdi/download_large_list_outside.asp). The data is in file BankDataSet.csv. You are working as a business analyst for an investment firm to evaluate the health of the U.S. Banking sector, as well as to identify higher performing Banks in the sector.
#
# The following list provides the description of the variables in the dataset:
# *   **Bank Name** =	 Registered Name of the Bank
# *   **city** =	 Registered City of Operations
# *   **stalp** =	 Registered State of operations
# *   **zip** =	 Zip Code of Bank
# *   **Repdte** =	 Bank Reporting date
# *   **Reporting Year** =	 Reporting Year
# *   **Employees** =	 Total number of Employees
# *   **Total Assets(000)** =	 Total Banking Assets,  including Liabilities and Capital at end of period (in millions of dollars)
# *   **CashBalance(000)** =	 Cash Balance of Bank  at end of report period (in millions of dollars)
# *   **Liabilities(000)** =	 Total Bank Liabilities in( millions of Dollars)
# *   **Deposits** =	 Total Bank Deposits in (millions of dollars)
#
# Banks are required to hold a portion of their Deposits in Cash. The requirements are given in file, **CashRatio.csv**.
#
# **Below are the questions that youy will need to answer. Answers are provided for you. Your objective is to write code to answer the questions and get a correct answer. You can have as many cells as you need for each question.**
#
# **Remark:** Several questions will ask you to create new columns. Feel free to create abbreviations(for example KPI1, KPI2, etc. - whatever helps you write code and understand it) and not use full descriptions of the variables as column names.

# %% [markdown]
# **0.** Import the libraries you are using for this assignment:

# %% [markdown]
# **1.** Import data files from your github: call **BanksData.csv** **banks**, **CashRatio.csv** - **cashratio**. Display first three 3 wows of both tables.

# %% [markdown]
# **2.** Create a new column, **Bank classification**, according to the following formula and :
#
#
# *   **Small**, if **Total Assessts(000)** < 100,000
# *   **Medium**, if 100,000 <= **Total Assessts(000)** <= 1,000,000
# *   **Large**, if **Total Assessts(000)** > 1,000,000
#
# Display first 3 rows of **banks** data table.
#
# **Hint:** https://www.geeksforgeeks.org/python3-if-if-else-nested-if-if-elif-statements/

# %% [markdown]
# **Answer:**

# %% [markdown]
# **3.**  Create new column, **Cash requirements**, calculate the **Cash requirements** for all banks according to the following formula:
#
# **Cash requirements = Reserve Ratio x Deposits**
#
# What is the average cash requirement for **Medium**-Size Banks? Round your answer to three decimal places.

# %% [markdown]
# **Answer:**

# %% [markdown]
# **4.** What is the minimum, average, and maximum **Cash requirements** for each bank size (**Bank classification**)? Round your answers to three decimal places.

# %% [markdown]
# **Answer:**

# %% [markdown]
# **5.**  Create new columns for the following financial ratios:
#
# *   **Liabilities to Assets = Liabilities(000) / Total Assets(000)**
# *   **Assets per Employee = Total Assets(000) / Employees**
# *   **Cash Balance to Cash Requirements = Cash Balance/ Cash Requirements**
#
# Display first 3 rows.

# %% [markdown]
# **6.** Determine if the following statement is **TRUE** or **FALSE**:
#
# *In 2019, Banks in New York had the highest Average Total Asset/Employee ratio than banks in the other 3 states.*

# %% [markdown]
# **Answer:**

# %% [markdown]
# **7.** Determine if the following statement is **TRUE** or **FALSE**:
#
# *In 2020, the Average Asset to Employee ratio for Banks in Illinois was lower than for 2019.*

# %% [markdown]
# **Answer:**

# %% [markdown]
# **8.** Which of the following statements is(are) **TRUE**?
#
# 1.   Large Banks in California have higher Average Liabilities/Total Asset Ratio than those in Illinois or Massachusetts.
# 2.   Small banks in Massachusetts have lower Average Liabilities/Total Asset Ratio than those in New York and California.
# 3.   Medium Size Banks in Illinois have higher Average Liabilities/Total Assets Ratio than California.
# 4.   Small Banks in Illinois have higher Average Liabilities/Total Assets ratios than Medium-size banks in California.
# 5.   Small banks in California have higher average Total Assets per Employee than those in Massachusetts and Illinois.
# 6.   None of teh above statements is true.

# %% [markdown]
# **Answer:**

# %% [markdown]
# **9.** In examining the average of Cash Balance/Cash Requirements for Banks between 2019 and 2021, and determine which of the following statements is (are) **TRUE**.
#
# 1.   Large banks had larger increase in cash balance/cash requirement ratio than medium-size and small banks.
# 2.   The increase in cash balance/cash requirement ratio for medium-size banks was smaller than for small banks.
# 3.   The increase in cash balance/cash requirements for Medium-size banks was higher than for Large Banks.
# 4.   None of the above statements is true.

# %% [markdown]
# **Answer:**

# %% [markdown]
# **10.** Create a line graph that has 3 trajectories representing the average of Cash Balance/Cash Requirements for different Bank classification by year.

# %% [markdown]
# **Answer:**

# %% [markdown]
# **11.** In examining the average of Cash Balance/Cash Requirements for Banks in 2019 and 2021, which of the following statements is **NOT TRUE**?
#
#
# 1.   The maximum value of Cash Balance/Cash Requirement ratio for Large banks in 2021 was over 6000.
# 2.   The standard deviation of Cash Balance/Cash Requirement ratio for Large banks in 2019, 2020 and 2021 were about the same.
# 3.   The maximum value of Cash Balance/Cash Requirements ratio for Medium size  banks in 2019 was under 100.
# 4.   In comparing with the average Cash Balance/Cash Requirements ratio with the maximum values, there may be recording or reporting data issues with specific banks in terms of their data on Cash Balances.
# 5.   All of the above are true.

# %% [markdown]
# **Answer**:

# %% [markdown]
# **Below create at least 3 questions and answer them using Python code, graphs, etc.**
